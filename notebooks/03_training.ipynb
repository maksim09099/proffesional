# %% [markdown]
# # 03 Training
# Обучение классификатора лиц на PyTorch.

# %%
from src.models.training import train_model
out = train_model()
out

# %%
import json
json.load(open('reports/training_history.json', encoding='utf-8'))[-1]
