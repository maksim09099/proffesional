# %% [markdown]
# # 05 API Demo
# Пример локального вызова FastAPI /predict.

# %%
import requests
url='http://127.0.0.1:8000/predict'
with open('path_to_image.jpg','rb') as f:
    r=requests.post(url, files={'file':('img.jpg',f,'image/jpeg')})
print(r.status_code)
print(r.json())
