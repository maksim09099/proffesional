# %% [markdown]
# # 01 Data Audit
# Аудит архивов Data1..Data4, структура и проблемы.

# %%
from src.data.data_audit import run_data_audit
result = run_data_audit()
result

# %%
import pandas as pd
pd.read_csv('reports/data_audit_report.csv').head()
