# %% [markdown]
# # 02 Preprocessing
# Детекция лиц, кроп и формирование train/val.

# %%
from src.data.preprocessing import build_processed_dataset
summary = build_processed_dataset()
summary

# %%
import json
json.load(open('reports/preprocessing_summary.json', encoding='utf-8'))
